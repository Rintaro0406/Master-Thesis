# %% [markdown]
# ## GCNN Seminar 7.6.2023
# ## This code was initially to estimate reasonable prior
# ## But it sucks
# ## 1. Train with flask maps test with T17 maps(N-body simulation)
# ## 2. The lowest NSIDE which DeepSphere can be trained, so NSIDE=32 for simplicity
# ## 3. Use Daniel's advice says MSE loss is going to trash, because it induces bias. But I use here MSE for simplicity(and not so long to train)
# #### 6.6.2023

# %%
#%matplotlib notebook
import os
os.chdir("../../מייַ_2023/prior_consideration")
import healpy as heal
import numpy as np
import tensorflow as tf
import keras_tuner as kt
from healpy_networks_custom import HealpyGCNN
import healpy_layers_custom as hp_layer
from tensorflow import keras
from tensorboard.plugins.hparams import api as hp
import matplotlib.pyplot as plt
from standard_2D import Standardize_Min_Max_2D, Rescale_MSE_Min_Max_2D
import build_model
from Loss_mean import MyLoss
from livelossplot import PlotLossesKeras
from cov_by_hand import cov, chisq
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
from getdist import plots, MCSamples
import getdist
import matplotlib.pyplot as plt

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 3 Physical GPUs, 3 Logical GPUs

# %% [markdown]
# # 1. Loading and preprocessing the data

# %% [markdown]
# ##### 1000 cosmology * 10  realization, so 10000 flask maps for training and validation datasets
# ##### 1 cosmology(fiducial) * 108 realization, so 108 maps for test datasets

# %%
training_data   = np.load('/project/ls-gruen/users/r.kanaki/Masterarbeit/Hirosaki_universe/prior/Kappa_Field/train_Gauss_1000_10.npz')
testing_data    = np.load('/project/ls-gruen/users/r.kanaki/Masterarbeit/Takahashi/bin34/T17_downgraded_to_32.npz')

# %%
train_data            = training_data['lognormal_map']
test_data             = testing_data['lognormal_map']
train_label_Omega_M       = training_data['Omega_M']
train_label_sigma_8       = training_data['sigma_8']
test_label_Omega_M        = testing_data['Omega_M']
test_label_sigma_8        = testing_data['sigma_8']

# %%
fiducial_Omega_M=test_label_Omega_M[0]
fiducial_sigma_8=test_label_sigma_8[0]

# %%
train_labels      = np.zeros((10000,2))
test_labels       = np.zeros((108,2))
for i in range(len(train_label_Omega_M)):
    train_labels[i]=np.array((train_label_Omega_M[i], train_label_sigma_8[i]))
for i in range(len(test_label_Omega_M)):
    test_labels[i]=np.array((test_label_Omega_M[i], test_label_sigma_8[i]))

# %%
x_train      = train_data.astype(np.float32)[..., None]
x_test       = test_data.astype(np.float32)[...,None]
np.random.RandomState(11).shuffle(x_train)
labels_train=train_labels.astype(np.float32)
np.random.RandomState(11).shuffle(labels_train)
labels_test=test_labels.astype(np.float32)

# %%
# %matplotlib inline

# %% [markdown]
# #### 1. Actually not good to use validation split, it destroys LHS sampling

# %% [markdown]
# ### 1.1 Make plot and check where is our fiducial cosmology

# %%
plt.figure(figsize=(8,8))
plt.scatter(train_label_Omega_M, train_label_sigma_8, s=10,label="train data")
plt.scatter(fiducial_Omega_M, fiducial_sigma_8, s=30, label="Hirosaki universe")
plt.xlabel("$\Omega_M$")
plt.ylabel("$\sigma_8$")
plt.legend();

# %% [markdown]
# ## 2. GCNN

# %% [markdown]
# ### 2.1 Considering what I am doing now

# %% [markdown]
# ### 2.1.1 Ponint Estimmate
# #### Just using MSE loss as usual from January. I think, it is defined like this
# #### $loss=\frac{1}{N_s-1}\sum^{N_s}_{i=1}(\theta-\theta_{true})^2$
# #### where $\theta$ is parameter of model, $\theta_{true}$ is true value which only dedushka knows (label) and $N_s$ is number of universe which dedushka made

# %% [markdown]
# ### 2.2 Train GCNN

# %%
nside=32
npix = heal.nside2npix(nside)
indices = np.arange(npix)

# %% [markdown]
# #### For MSE loss

# %%
layers =[hp_layer.HealpyChebyshev(K=10, Fout=5, use_bias=False, use_bn=True,          #1
                                       activation="relu", kernel_regularizer=None),
                  hp_layer.HealpyPool(p=1),                                          #2
                  hp_layer.HealpyChebyshev(K=10, Fout=5, use_bias=False, use_bn=True, #3
                                       activation="relu", kernel_regularizer=None),
                  hp_layer.HealpyPool(p=1),                                          #4
                  hp_layer.HealpyChebyshev(K=10, Fout=5, use_bias=False, use_bn=True, #5
                                       activation="relu", kernel_regularizer=None),
                  hp_layer.HealpyPool(p=1),                                          #6   
                  hp_layer.HealpyChebyshev(K=10, Fout=5, use_bias=False, use_bn=True, #7
                                       activation="relu", kernel_regularizer=None),
                  hp_layer.HealpyPool(p=1),                                          #8   
                  hp_layer.HealpyChebyshev(K=10, Fout=5, use_bias=False, use_bn=True, #9
                                       activation="relu", kernel_regularizer=None),  
                  tf.keras.layers.Flatten(),                                         #10
                  tf.keras.layers.Dense(2,use_bias=False)]                           #11
model_MSE = HealpyGCNN(nside=nside, indices=indices, layers=layers, n_neighbors=20)      
model_MSE.build(input_shape=(None, len(indices), 1)) 
model_MSE.summary()
# Out:
# WARNING: This network assumes that everything concerning healpy is in NEST ordering...
# Detected a reduction factor of 16.0, the input with nside 32 will be transformed to 2 during a forward pass. Checking for consistency with indices...
# indices seem consistent...
# Model: "healpy_gcnn_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  chebyshev (Chebyshev)       (None, 12288, 5)          60
#
#  healpy_pool (HealpyPool)    (None, 3072, 5)           0
#
#  chebyshev_1 (Chebyshev)     (None, 3072, 5)           260
#
#  healpy_pool_1 (HealpyPool)  (None, 768, 5)            0
#
#  chebyshev_2 (Chebyshev)     (None, 768, 5)            260
#
#  healpy_pool_2 (HealpyPool)  (None, 192, 5)            0
#
#  chebyshev_3 (Chebyshev)     (None, 192, 5)            260
#
#  healpy_pool_3 (HealpyPool)  (None, 48, 5)             0
#
#  chebyshev_4 (Chebyshev)     (None, 48, 5)             260
#
#  flatten (Flatten)           (None, 240)               0
#
#  dense (Dense)               (None, 2)                 480
#
# =================================================================
# Total params: 1,580
# Trainable params: 1,530
# Non-trainable params: 50
# _________________________________________________________________

# %% [markdown]
# ### Here you can see 12288 at first layer, it is the number of pixel for NSIDE=32
# ### so 12*32*32=12288
# ### F_out is the number of output
# ### K is corresponding to the order of Chebyshev polynomial and also K-nearest neighbours
# ### Higher K more exact, but it is trade off with computational expense

# %% [markdown]
# #### Except last dense layer, both models are identical

# %%
path_MSE='callbacks/Compare_loss'
callbacks_MSE = tf.keras.callbacks.ModelCheckpoint(
            filepath=path_MSE,
            save_weights_only=True,
            monitor='val_loss',
            mode='min',
            save_best_only=True)

# %%
model_MSE.compile(optimizer=tf.keras.optimizers.Adam(0.0004),
              loss="mean_squared_error",
              metrics=[tf.keras.metrics.MeanSquaredError()],
)

# %%
history_MSE = model_MSE.fit(
    x_train,
    labels_train,
    batch_size=32,
    epochs=100,
    validation_split=0.2,
    callbacks=[callbacks_MSE])
# Out:
# Epoch 1/100
# 250/250 [==============================] - 4s 11ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 2/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 3/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 4/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 5/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 6/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 7/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 8/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 9/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 10/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 11/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 12/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 13/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 14/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 15/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 16/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 17/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 18/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 19/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 20/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 21/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 22/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 23/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 24/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 25/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 26/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 27/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 28/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 29/100
# 250/250 [==============================] - 3s 11ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 30/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 31/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 32/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 33/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 34/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 35/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 36/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 37/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 38/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 39/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 40/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 41/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 42/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 43/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 44/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 45/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 46/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 47/100
# 250/250 [==============================] - 3s 11ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 48/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 49/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 50/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 51/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 52/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 53/100
# 250/250 [==============================] - 3s 11ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 54/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 55/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 56/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 57/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 58/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 59/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 60/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 61/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 62/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 63/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 64/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 65/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 66/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 67/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 68/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 69/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 70/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 71/100
# 250/250 [==============================] - 3s 11ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 72/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 73/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 74/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 75/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 76/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 77/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 78/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 79/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 80/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 81/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 82/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 83/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 84/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 85/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 86/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 87/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 88/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 89/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 90/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 91/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 92/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 93/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 94/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 95/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 96/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 97/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 98/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 99/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 100/100
# 250/250 [==============================] - 3s 10ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0097 - val_mean_squared_error: 0.0097

# %% [markdown]
# ### 2.3 Loss functions

# %%
plt.figure(figsize=(20,10))
plt.plot(history_MSE.history["loss"], label="training")
plt.plot(history_MSE.history["val_loss"], label="validation")
plt.grid()
#plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ### 2.4 Test evaluation

# %%
prediction_MSE=model_MSE.predict(test_data)
#prediction_NLL=model_NLL.predict(test_data)
Omega_M_MSE_MSE = 1. / len(prediction_MSE[:,0]) * np.sum((labels_test[:,0]-prediction_MSE[:,0])**2)
sigma_8_MSE_MSE = 1. / len(prediction_MSE[:,1]) * np.sum((labels_test[:,1]-prediction_MSE[:,1])**2)
#Omega_M_MSE_NLL = 1. / len(prediction_NLL[:,0]) * np.sum((labels_test[:,0]-prediction_NLL[:,0])**2)
#sigma_8_MSE_NLL = 1. / len(prediction_NLL[:,1]) * np.sum((labels_test[:,1]-prediction_NLL[:,1])**2)
print("MSE loss using MSE")
print("$\Omega_m$:", Omega_M_MSE_MSE)
print("$\sigma_8$:", sigma_8_MSE_MSE)
#print("MSE loss using NLL")
#print("$\Omega_m$:", Omega_M_MSE_NLL)
#print("$\sigma_8$:", sigma_8_MSE_NLL)
# Out:
# MSE loss using MSE
# $\Omega_m$: 0.016637848483191595
# $\sigma_8$: 0.05113795510044804

# %%
prediction_train = model_MSE.predict(train_data)

# %%
plt.figure(figsize=(12,12))
plt.scatter(prediction_train[:,0],prediction_train[:,1], label=f'Estimation from GCNN model trained by Gaussian maps',s=5)
plt.scatter(train_label_Omega_M, train_label_sigma_8, s=10,label="train data")
plt.legend(fontsize=10)
plt.ylabel(f"$\sigma_8$", fontsize=20)
plt.xlabel(f"$\Omega_m$", fontsize=20)
# Out:
# Text(0.5, 0, '$\\Omega_m$')

# %%
plt.figure(figsize=(12,12))
plt.scatter(prediction_MSE[:,0],prediction_MSE[:,1], label=f'Estimation from GCNN using MSE loss',s=5)
#plt.scatter(prediction_NLL[:,0],prediction_NLL[:,1], label=f'Estimation from GCNN using NLL loss',s=5)
plt.scatter(fiducial_Omega_M, fiducial_sigma_8, label='fiducial Cosmology', s=50, color="red")
plt.legend()
plt.ylabel(f"$\sigma_8$")
plt.xlabel(f"$\Omega_m$")
# Out:
# Text(0.5, 0, '$\\Omega_m$')

# %% [markdown]
# ## 3. Covariance

# %% [markdown]
# ## 3.1 Get Covariance

# %% [markdown]
# ### 3.1.1 MSE Covariance
# #### $C_{i,j}=\frac{1}{N_s-1}\sum^{N_s}_{s=1}(\theta-\langle\theta\rangle)^T(\theta-\langle\theta\rangle)$

# %%
mu_MSE   = np.array((np.mean(prediction_MSE[:,0]),np.mean(prediction_MSE[:,1]))).T
cov_MSE  = cov(mu_MSE, prediction_MSE)

# %%
f = plt.figure(figsize=(13, 13))
plt.matshow(cov_MSE, fignum=f.number)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ## 4 Plot Posterior

# %%
ndim         = 2
nsamp        = 1000000
random_state = np.random.default_rng(10)
samps_MSE    = random_state.multivariate_normal(mu_MSE, cov_MSE, size=nsamp)
#samps_NLL = random_state.multivariate_normal(mu_est, cov_NLL, size=nsamp)

# %%
names = ['x1', 'x2']
labels =  ["\Omega_m", "\sigma_8"]
samples_MSE = MCSamples(samples=samps_MSE,names = names, labels = labels, label='MSE loss')
#samples_NLL = MCSamples(samples=samps_NLL,names = names, labels = labels, label='Negative Log Gaussian likelihood loss')
# Out:
# Removed no burn in

# %%
g = plots.get_single_plotter(width_inch=10, ratio=1)
g.plot_2d(samples_MSE, 'x1', 'x2', filled=True)
g.add_legend('MSE loss', legend_loc='upper right');
